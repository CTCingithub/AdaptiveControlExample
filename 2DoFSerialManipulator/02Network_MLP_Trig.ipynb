# %% [markdown]
# # MLP Network

# %% [markdown]
# ## 1. Pretreatment

# %% [markdown]
# Import Configuration.

# %%
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import yaml

import torch
import torch.nn as nn
from torchinfo import summary

with open("./config/MLP.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# Import data.

# %%
InputData = sp.io.loadmat(config["DATA_LOADER"]["INPUT_DATA_PATH"])
InputData = torch.from_numpy(InputData["KinematicsData"])
OutputData = sp.io.loadmat(config["DATA_LOADER"]["OUTPUT_DATA_PATH"])
OutputData = torch.from_numpy(OutputData["DynRegData"])

# %% [markdown]
# Import `NN_utils` and `Visualization`.

# %%
import sys

sys.path.append("../utils")
from Blocks import *
from NN_utils import *
from Visualization import *

SETUP_SEED(42)
torch.set_default_dtype(torch.float64)

# %% [markdown]
# Size of input and output data.

# %%
InputData.shape, OutputData.shape
# Out:
# (torch.Size([50000, 8]), torch.Size([50000, 14]))

# %% [markdown]
# Create **Training**, **Validation** and **Test** datasets.

# %%
TrainingLoader, ValidationLoader, TestLoader = Split2Loaders(
    InputData, OutputData, config
)

# %% [markdown]
# ## 2. Training

# %% [markdown]
# Define MLP network structure.

# %%
class DynReg_MLP(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=None, sliding_pair=False):
        if hidden_size is None:
            hidden_size = [16, 32, 16]
        super().__init__()
        # Degree of Freedom
        self.DoF = input_size // 4
        # Triangular Layer
        self.TrigLayer = Triangular(SlidingPair=sliding_pair)
        # Linear Layer List
        self.NN = nn.ModuleList()
        self.NNStruct = (
            [input_size + self.DoF * (sliding_pair + 1)] + hidden_size + [output_size]
        )

        for i in range(len(self.NNStruct) - 1):
            self.NN.append(nn.Linear(self.NNStruct[i], self.NNStruct[i + 1]))

    def forward(self, x):
        Output = self.TrigLayer(x)
        for layer in self.NN:
            Output = layer(Output)
            if layer != self.NN[-1]:
                Output = torch.relu(Output)
        return Output

# %% [markdown]
# Define network.

# %%
Net = DynReg_MLP(
    input_size=config["NETWORK"]["INPUT_SIZE"],
    output_size=config["NETWORK"]["OUTPUT_SIZE"],
    hidden_size=config["NETWORK"]["HIDDEN_SIZE"],
    sliding_pair=False,
)
summary(
    Net,
    input_data=torch.zeros(1, InputData.shape[1]),
    device=GET_DEVICE(),
    col_names=["input_size", "output_size", "num_params"],
    col_width=15,
)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                   Input Shape     Output Shape    Param #
# =====================================================================================
# DynReg_MLP                               [1, 8]          [1, 14]         --
# ├─Triangular: 1-1                        [1, 8]          [1, 10]         --
# ├─ModuleList: 1-2                        --              --              --
# │    └─Linear: 2-1                       [1, 10]         [1, 32]         352
# │    └─Linear: 2-2                       [1, 32]         [1, 32]         1,056
# │    └─Linear: 2-3                       [1, 32]         [1, 32]         1,056
# │    └─Linear: 2-4                       [1, 32]         [1, 14]         462
# =====================================================================================
# Total params: 2,926
# Trainable params: 2,926
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# =====================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.03
# =====================================================================================

# %% [markdown]
# Define optimizer.

# %%
optimizer = torch.optim.Adam(
    Net.parameters(),
    lr=config["TRAIN"]["LEARNING_RATE"],
    weight_decay=config["TRAIN"]["WEIGHT_DECAY"],
)

# %% [markdown]
# Training network.

# %%
(
    Loss_Training_History,
    Loss_Validation_History,
) = TRAIN_WITH_PROGRESS_BAR_ONE_LOSS(
    MODEL=Net,
    CONFIG=config,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=TrainingLoader,
    VALIDATION_LOADER=ValidationLoader,
    LOSS_TYPE=nn.MSELoss(),
)
# Out:
# PyTorch Version: 2.5.1
# Weight initialized with Kaiming Initialization
# Training on cpu
# ====================================Start training====================================
# Epoch 1/50: 100%|██████████| 1875/1875 [00:04<00:00, 421.22batch/s, loss=2.15]
# Epoch 2/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.75batch/s, loss=0.804]
# Epoch 3/50: 100%|██████████| 1875/1875 [00:04<00:00, 462.04batch/s, loss=1.03]
# Epoch 4/50: 100%|██████████| 1875/1875 [00:03<00:00, 480.85batch/s, loss=0.648]
# Epoch 5/50: 100%|██████████| 1875/1875 [00:03<00:00, 487.40batch/s, loss=0.594]
# Epoch 6/50: 100%|██████████| 1875/1875 [00:03<00:00, 474.00batch/s, loss=0.371]
# Epoch 7/50: 100%|██████████| 1875/1875 [00:03<00:00, 486.12batch/s, loss=0.656]
# Epoch 8/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.50batch/s, loss=0.846]
# Epoch 9/50: 100%|██████████| 1875/1875 [00:04<00:00, 392.68batch/s, loss=0.6]
# Epoch 10/50: 100%|██████████| 1875/1875 [00:04<00:00, 376.22batch/s, loss=0.732]
# Epoch 11/50: 100%|██████████| 1875/1875 [00:05<00:00, 331.25batch/s, loss=0.427]
# Epoch 12/50: 100%|██████████| 1875/1875 [00:04<00:00, 395.42batch/s, loss=0.82]
# Epoch 13/50: 100%|██████████| 1875/1875 [00:04<00:00, 392.84batch/s, loss=0.646]
# Epoch 14/50: 100%|██████████| 1875/1875 [00:05<00:00, 367.35batch/s, loss=0.514]
# Epoch 15/50: 100%|██████████| 1875/1875 [00:04<00:00, 378.21batch/s, loss=0.537]
# Epoch 16/50: 100%|██████████| 1875/1875 [00:05<00:00, 345.51batch/s, loss=0.677]
# Epoch 17/50: 100%|██████████| 1875/1875 [00:05<00:00, 344.76batch/s, loss=0.795]
# Epoch 18/50: 100%|██████████| 1875/1875 [00:05<00:00, 325.28batch/s, loss=0.713]
# Epoch 19/50: 100%|██████████| 1875/1875 [00:04<00:00, 377.55batch/s, loss=0.761]
# Epoch 20/50: 100%|██████████| 1875/1875 [00:05<00:00, 352.54batch/s, loss=0.437]
# Epoch 21/50: 100%|██████████| 1875/1875 [00:04<00:00, 391.63batch/s, loss=0.496]
# Epoch 22/50: 100%|██████████| 1875/1875 [00:04<00:00, 394.94batch/s, loss=1.38]
# Epoch 23/50: 100%|██████████| 1875/1875 [00:04<00:00, 399.10batch/s, loss=0.467]
# Epoch 24/50: 100%|██████████| 1875/1875 [00:04<00:00, 385.81batch/s, loss=0.71]
# Epoch 25/50: 100%|██████████| 1875/1875 [00:05<00:00, 372.21batch/s, loss=0.391]
# Epoch 26/50: 100%|██████████| 1875/1875 [00:05<00:00, 361.23batch/s, loss=0.447]
# Epoch 27/50: 100%|██████████| 1875/1875 [00:05<00:00, 327.32batch/s, loss=0.769]
# Epoch 28/50: 100%|██████████| 1875/1875 [00:04<00:00, 385.49batch/s, loss=0.881]
# Epoch 29/50: 100%|██████████| 1875/1875 [00:04<00:00, 462.77batch/s, loss=0.49]
# Epoch 30/50: 100%|██████████| 1875/1875 [00:03<00:00, 471.14batch/s, loss=0.796]
# Epoch 31/50: 100%|██████████| 1875/1875 [00:03<00:00, 487.88batch/s, loss=0.396]
# Epoch 32/50: 100%|██████████| 1875/1875 [00:03<00:00, 481.19batch/s, loss=0.583]
# Epoch 33/50: 100%|██████████| 1875/1875 [00:04<00:00, 383.85batch/s, loss=0.56]
# Epoch 34/50: 100%|██████████| 1875/1875 [00:05<00:00, 345.30batch/s, loss=0.452]
# Epoch 35/50: 100%|██████████| 1875/1875 [00:04<00:00, 383.63batch/s, loss=0.328]
# Epoch 36/50: 100%|██████████| 1875/1875 [00:05<00:00, 365.43batch/s, loss=0.564]
# Epoch 37/50: 100%|██████████| 1875/1875 [00:05<00:00, 337.26batch/s, loss=0.481]
# Epoch 38/50: 100%|██████████| 1875/1875 [00:05<00:00, 324.59batch/s, loss=0.549]
# Epoch 39/50: 100%|██████████| 1875/1875 [00:05<00:00, 345.47batch/s, loss=0.615]
# Epoch 40/50: 100%|██████████| 1875/1875 [00:05<00:00, 361.43batch/s, loss=0.491]
# Epoch 41/50: 100%|██████████| 1875/1875 [00:04<00:00, 439.49batch/s, loss=0.587]
# Epoch 42/50: 100%|██████████| 1875/1875 [00:04<00:00, 448.09batch/s, loss=0.433]
# Epoch 43/50: 100%|██████████| 1875/1875 [00:04<00:00, 441.69batch/s, loss=0.802]
# Epoch 44/50: 100%|██████████| 1875/1875 [00:04<00:00, 383.47batch/s, loss=0.324]
# Epoch 45/50: 100%|██████████| 1875/1875 [00:04<00:00, 465.41batch/s, loss=0.732]
# Epoch 46/50: 100%|██████████| 1875/1875 [00:04<00:00, 455.00batch/s, loss=0.575]
# Epoch 47/50: 100%|██████████| 1875/1875 [00:05<00:00, 369.40batch/s, loss=0.611]
# Epoch 48/50: 100%|██████████| 1875/1875 [00:05<00:00, 358.80batch/s, loss=0.421]
# Epoch 49/50: 100%|██████████| 1875/1875 [00:04<00:00, 391.14batch/s, loss=0.525]
# Epoch 50/50: 100%|██████████| 1875/1875 [00:04<00:00, 388.56batch/s, loss=0.415]
# ====================================Finish training====================================

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# Loss-Epoch Diagram

# %%
plt.rcParams["text.usetex"] = True
Loss_Epoch_Diagram = LOSS_EPOCH_DIAGRAM_ONE_LOSS(
    LOSS_HISTORY_TUPLE=(
        Loss_Training_History,
        Loss_Validation_History,
    ),
    CONFIG=config,
)

# %% [markdown]
# Final loss.

# %%
Loss_Validation_History[-1]
# Out:
# 0.4534699094303692

# %% [markdown]
# Linear Layer Weight Visualization.

# %%
def VISUALIZE_Weight(NN, CONFIG, sliding_pair=False):
    NUM_LAYERS = len(NN)
    NUM_ROW = 1
    NUM_COL = NUM_LAYERS
    INPUT_SHAPE = NN[0].weight.shape[1]
    FIG_SIZE = [NUM_COL * 4, 4]
    fig, ax = plt.subplots(NUM_ROW, NUM_COL, figsize=FIG_SIZE, dpi=CONFIG["DPI"])
    for i in range(NUM_LAYERS):
        VISUALIZE_MATRIX_AX(
            ax[i],
            NN[i].weight.detach().to("cpu").numpy(),
            CONFIG,
            f"Layer {i+1}'s Weight",
        )
        if i == 0:
            ax[i].set_xticks(
                int(INPUT_SHAPE / (5 + sliding_pair)) * np.arange(1, 6 + sliding_pair)
            )
            TickLabels = [
                r"$\sin(q_{i})$",
                r"$\cos(q_{i})$",
                r"$\dot{q}_{i}$",
                r"$\phi_{i}$",
                r"$\psi_{i}$",
            ]
            if sliding_pair:
                TickLabels = [r"$q_{i}$"] + TickLabels
            ax[i].set_xticklabels(TickLabels)
    plt.tight_layout()
    return fig

# %%
NN_Weight = VISUALIZE_Weight(Net.NN, config["VISUALIZATION"]["NN_WEIGHT"])

# %% [markdown]
# ## 4. Error on Test Data

# %% [markdown]
# Test Data

# %%
test_input_data = []
test_output_data = []
for data in TestLoader:
    test_input_data += data[0].detach().to(GET_DEVICE(config["TRAIN"]["DEVICE"]))
    test_output_data += data[1].detach().to("cpu")

test_output_fromData = torch.stack(test_output_data).numpy()

# %% [markdown]
# Obtain output computed from model.

# %%
Net.eval()
test_ouput_fromModel = torch.stack(
    [Net(test_input).detach().to("cpu") for test_input in test_input_data]
).numpy()

# %% [markdown]
# Compute standard deviation and extreme error of each element.

# %%
import itertools

StandardDeviation = np.zeros((1, test_ouput_fromModel.shape[1]))
ExtremeError = test_ouput_fromModel[:2, :] - test_output_fromData[:2, :]
for i, j in itertools.product(
    range(test_ouput_fromModel.shape[0]), range(test_ouput_fromModel.shape[1])
):
    StandardDeviation[:, j] += np.power(
        test_ouput_fromModel[i, j] - test_output_fromData[i, j], 2
    )
    ExtremeError[0, j] = max(
        ExtremeError[0, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
    ExtremeError[1, j] = min(
        ExtremeError[1, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
StandardDeviation = np.sqrt(StandardDeviation) / test_ouput_fromModel.shape[0]
StandardDeviation = StandardDeviation.reshape(
    -1,
).tolist()
UpperError = ExtremeError[0, :].tolist()
LowerError = ExtremeError[1, :].tolist()

# %% [markdown]
# Visualization.

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Standard Deviation
axs[0].bar(np.arange(len(StandardDeviation)) + 1, StandardDeviation, zorder=5)
for i in range(len(StandardDeviation)):
    axs[0].text(
        i + 1,
        StandardDeviation[i],
        "{:.4f}".format(StandardDeviation[i]),
        ha="center",
        va="bottom",
        zorder=1,
    )
axs[0].set_xticks(np.arange(len(StandardDeviation)) + 1)
axs[0].set_xlim([1 - 0.8, len(StandardDeviation) + 0.8])
axs[0].set_title("Standard Deviation of MLP", fontsize=20)
axs[0].set_xlabel("Term", fontsize=15)
axs[0].set_ylabel("Standard Deviation", fontsize=15)
axs[0].grid(axis="y", linestyle="--", zorder=-1)


# Upper Error
axs[1].bar(np.arange(len(UpperError)) + 1, UpperError, zorder=5)
# Lower Error
axs[1].bar(np.arange(len(LowerError)) + 1, LowerError, zorder=5)
for i in range(len(UpperError)):
    axs[1].text(
        i + 1,
        UpperError[i],
        "{:.4f}".format(UpperError[i]),
        ha="center",
        va="bottom",
        zorder=1,
    )
    axs[1].text(
        i + 1,
        LowerError[i],
        "{:.4f}".format(LowerError[i]),
        ha="center",
        va="top",
        zorder=1,
    )
axs[1].set_xticks(np.arange(len(UpperError)) + 1)
axs[1].set_xlim([1 - 0.8, len(UpperError) + 0.8])
axs[1].set_title("Extreme Error of MLP", fontsize=20)
axs[1].set_xlabel("Term", fontsize=15)
axs[1].set_ylabel("Min/Max Error", fontsize=15)
axs[1].grid(axis="y", linestyle="--", zorder=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram of dominating error terms.

# %%
HistedTermIndex = [4, 5, 11, 12]
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for i in range(4):
    axs[int(np.floor(i / 2)), np.mod(i, 2)].hist(
        test_ouput_fromModel[:, HistedTermIndex[i]]
        - test_output_fromData[:, HistedTermIndex[i]],
        bins=50,
    )
    axs[int(np.floor(i / 2)), np.mod(i, 2)].set_xlabel("Error", fontsize=15)
    axs[int(np.floor(i / 2)), np.mod(i, 2)].set_title(
        "Error Histogram of Term {}".format(HistedTermIndex[i]+1), fontsize=20
    )

plt.tight_layout()
plt.show()
