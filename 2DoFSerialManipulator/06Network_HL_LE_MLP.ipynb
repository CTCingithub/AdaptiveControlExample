# %% [markdown]
# # Linear Embedding MLP Network with Hadamard Layer

# %% [markdown]
# ## 1. Pretreatment

# %% [markdown]
# Read data from `.mat` files.

# %%
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import yaml

import torch
import torch.nn as nn
from torchinfo import summary

with open("./config/HL_LE_MLP.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# Import data.

# %%
InputData = sp.io.loadmat(config["DATA_LOADER"]["INPUT_DATA_PATH"])
InputData = torch.from_numpy(InputData["KinematicsData"])
OutputData = sp.io.loadmat(config["DATA_LOADER"]["OUTPUT_DATA_PATH"])
OutputData = torch.from_numpy(OutputData["DynRegData"])

# %% [markdown]
# Import `NN_utils` and `Visualization`.

# %%
import sys

sys.path.append("../utils")
from NN_utils import *
from Visualization import *

SETUP_SEED(42)
torch.set_default_dtype(torch.float64)

# %% [markdown]
# Size of input and output data.

# %%
InputData.shape, OutputData.shape
# Out:
# (torch.Size([50000, 8]), torch.Size([50000, 14]))

# %% [markdown]
# Create **Training**, **Validation** and **Test** datasets.

# %%
TrainingLoader, ValidationLoader, TestLoader = Split2Loaders(
    InputData, OutputData, config
)

# %% [markdown]
# ## 2. Training

# %% [markdown]
# Define Hadmard Layer.

# %%
def HadamardLayer(X, ScaleFactor, Bias):
    return ScaleFactor * X + Bias

# %% [markdown]
# Define MLP network structure.

# %%
class DynReg_MLP(nn.Module):
    def __init__(self, input_size, output_size, embedding_size, hidden_size=None):
        if hidden_size is None:
            hidden_size = [16, 32, 16]
        super().__init__()

        # Linear Layer List
        self.NN = nn.ModuleList()

        self.NNStruct = [input_size] + hidden_size + [embedding_size]
        for i in range(len(self.NNStruct) - 1):
            self.NN.append(nn.Linear(self.NNStruct[i], self.NNStruct[i + 1]))

        self.LinearMapping = nn.Linear(embedding_size, output_size, bias=False)

    def forward(self, x):
        Output = x
        for layer in self.NN:
            Output = layer(Output)
            Output = torch.relu(Output)
        # Output = HadamardLayer(Output)
        # Output = self.LinearMapping(Output)
        return Output

# %% [markdown]
# Define network.

# %%
Net = DynReg_MLP(
    input_size=config["NETWORK"]["INPUT_SIZE"],
    output_size=config["NETWORK"]["OUTPUT_SIZE"],
    embedding_size=config["NETWORK"]["EMBEDDING_SIZE"],
    hidden_size=config["NETWORK"]["HIDDEN_SIZE"],
)
summary(
    Net,
    input_data=torch.zeros(1, InputData.shape[1]),
    device=GET_DEVICE(),
    col_names=["input_size", "output_size", "num_params"],
    col_width=15,
)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                   Input Shape     Output Shape    Param #
# =====================================================================================
# DynReg_MLP                               [1, 8]          [1, 8]          112
# ├─ModuleList: 1-1                        --              --              --
# │    └─Linear: 2-1                       [1, 8]          [1, 16]         144
# │    └─Linear: 2-2                       [1, 16]         [1, 32]         544
# │    └─Linear: 2-3                       [1, 32]         [1, 8]          264
# =====================================================================================
# Total params: 1,064
# Trainable params: 1,064
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# =====================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# =====================================================================================

# %% [markdown]
# Define loss function.

# %%
def SparityLoss(SparityPromotingLayer, OutputFromNet, OutputFromData):
    sparity_loss = 0
    for layer in SparityPromotingLayer:
        for _, param in layer.named_parameters():
            sparity_loss += torch.abs(param).sum()

    return sparity_loss

# %% [markdown]
# Define optimizer.

# %%
optimizer = torch.optim.Adam(
    Net.parameters(),
    lr=config["TRAIN"]["LEARNING_RATE"],
    weight_decay=config["TRAIN"]["WEIGHT_DECAY"],
)

# %% [markdown]
# Training network.

# %%
(
    Loss_1_Training_History,
    Loss_1_Validation_History,
    Loss_2_Training_History,
    Loss_2_Validation_History,
) = TRAIN_WITH_PROGRESS_BAR_TWO_LOSS(
    MODEL=Net,
    CONFIG=config,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=TrainingLoader,
    VALIDATION_LOADER=ValidationLoader,
    LOSS_TUPLE=[
        nn.MSELoss(),
        lambda y1, y2: SparityLoss(
            [
                Net.LinearMapping,
            ],
            y1,
            y2,
        ),
    ],
    FREEZE_LAYER=[
        Net.LinearMapping,
    ],
)
# Out:
# PyTorch Version: 2.2.2
# Weight initialized with Kaiming Initialization
# Training on cpu
# ====================================Start training====================================
# Epoch 1/50: 100%|██████████| 1875/1875 [00:04<00:00, 434.09batch/s, loss_1=21.9, loss_2=21.8]
# Epoch 2/50: 100%|██████████| 1875/1875 [00:04<00:00, 446.24batch/s, loss_1=6.78, loss_2=6.55]
# Epoch 3/50: 100%|██████████| 1875/1875 [00:04<00:00, 450.08batch/s, loss_1=5.75, loss_2=5.51]
# Epoch 4/50: 100%|██████████| 1875/1875 [00:04<00:00, 457.08batch/s, loss_1=3.62, loss_2=3.38]
# Epoch 5/50: 100%|██████████| 1875/1875 [00:04<00:00, 448.10batch/s, loss_1=2.97, loss_2=2.72]
# Epoch 6/50: 100%|██████████| 1875/1875 [00:04<00:00, 461.76batch/s, loss_1=2.67, loss_2=2.43]
# Epoch 7/50: 100%|██████████| 1875/1875 [00:03<00:00, 469.96batch/s, loss_1=2.4, loss_2=2.16]
# Epoch 8/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.45batch/s, loss_1=2.64, loss_2=2.41]
# Epoch 9/50: 100%|██████████| 1875/1875 [00:03<00:00, 475.41batch/s, loss_1=1.48, loss_2=1.26]
# Epoch 10/50: 100%|██████████| 1875/1875 [00:03<00:00, 472.19batch/s, loss_1=1.92, loss_2=1.71]
# Epoch 11/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.26batch/s, loss_1=2.75, loss_2=2.54]
# Epoch 12/50: 100%|██████████| 1875/1875 [00:03<00:00, 471.70batch/s, loss_1=2.01, loss_2=1.81]
# Epoch 13/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.81batch/s, loss_1=1.09, loss_2=0.889]
# Epoch 14/50: 100%|██████████| 1875/1875 [00:03<00:00, 473.99batch/s, loss_1=1.81, loss_2=1.62]
# Epoch 15/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.90batch/s, loss_1=1.58, loss_2=1.4]
# Epoch 16/50: 100%|██████████| 1875/1875 [00:04<00:00, 466.51batch/s, loss_1=1.02, loss_2=0.838]
# Epoch 17/50: 100%|██████████| 1875/1875 [00:04<00:00, 463.47batch/s, loss_1=1.22, loss_2=1.05]
# Epoch 18/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.26batch/s, loss_1=1.77, loss_2=1.61]
# Epoch 19/50: 100%|██████████| 1875/1875 [00:04<00:00, 465.78batch/s, loss_1=1.12, loss_2=0.959]
# Epoch 20/50: 100%|██████████| 1875/1875 [00:03<00:00, 469.18batch/s, loss_1=1.36, loss_2=1.2]
# Epoch 21/50: 100%|██████████| 1875/1875 [00:04<00:00, 464.77batch/s, loss_1=1.08, loss_2=0.927]
# Epoch 22/50: 100%|██████████| 1875/1875 [00:04<00:00, 466.09batch/s, loss_1=0.993, loss_2=0.842]
# Epoch 23/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.24batch/s, loss_1=0.892, loss_2=0.746]
# Epoch 24/50: 100%|██████████| 1875/1875 [00:04<00:00, 466.64batch/s, loss_1=1.2, loss_2=1.06]
# Epoch 25/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.17batch/s, loss_1=0.952, loss_2=0.814]
# Epoch 26/50: 100%|██████████| 1875/1875 [00:03<00:00, 472.53batch/s, loss_1=1.05, loss_2=0.914]
# Epoch 27/50: 100%|██████████| 1875/1875 [00:04<00:00, 465.84batch/s, loss_1=1.02, loss_2=0.889]
# Epoch 28/50: 100%|██████████| 1875/1875 [00:04<00:00, 461.20batch/s, loss_1=0.856, loss_2=0.727]
# Epoch 29/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.51batch/s, loss_1=1.32, loss_2=1.19]
# Epoch 30/50: 100%|██████████| 1875/1875 [00:03<00:00, 474.33batch/s, loss_1=1.27, loss_2=1.14]
# Epoch 31/50: 100%|██████████| 1875/1875 [00:03<00:00, 477.15batch/s, loss_1=1.31, loss_2=1.18]
# Epoch 32/50: 100%|██████████| 1875/1875 [00:03<00:00, 476.59batch/s, loss_1=1.03, loss_2=0.905]
# Epoch 33/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.77batch/s, loss_1=1.37, loss_2=1.24]
# Epoch 34/50: 100%|██████████| 1875/1875 [00:04<00:00, 468.41batch/s, loss_1=1.02, loss_2=0.896]
# Epoch 35/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.96batch/s, loss_1=1.19, loss_2=1.06]
# Epoch 36/50: 100%|██████████| 1875/1875 [00:03<00:00, 472.98batch/s, loss_1=1.48, loss_2=1.35]
# Epoch 37/50: 100%|██████████| 1875/1875 [00:03<00:00, 474.05batch/s, loss_1=0.829, loss_2=0.701]
# Epoch 38/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.55batch/s, loss_1=1.49, loss_2=1.36]
# Epoch 39/50: 100%|██████████| 1875/1875 [00:03<00:00, 472.91batch/s, loss_1=1.09, loss_2=0.964]
# Epoch 40/50: 100%|██████████| 1875/1875 [00:03<00:00, 472.22batch/s, loss_1=1.21, loss_2=1.08]
# Epoch 41/50: 100%|██████████| 1875/1875 [00:03<00:00, 471.48batch/s, loss_1=1.01, loss_2=0.88]
# Epoch 42/50: 100%|██████████| 1875/1875 [00:04<00:00, 463.87batch/s, loss_1=1.16, loss_2=1.03]
# Epoch 43/50: 100%|██████████| 1875/1875 [00:03<00:00, 471.40batch/s, loss_1=1.25, loss_2=1.12]
# Epoch 44/50: 100%|██████████| 1875/1875 [00:03<00:00, 469.06batch/s, loss_1=1.1, loss_2=0.973]
# Epoch 45/50: 100%|██████████| 1875/1875 [00:03<00:00, 471.14batch/s, loss_1=0.639, loss_2=0.512]
# Epoch 46/50: 100%|██████████| 1875/1875 [00:03<00:00, 470.69batch/s, loss_1=0.926, loss_2=0.799]
# Epoch 47/50: 100%|██████████| 1875/1875 [00:03<00:00, 469.90batch/s, loss_1=1, loss_2=0.874]
# Epoch 48/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.35batch/s, loss_1=0.94, loss_2=0.813]
# Epoch 49/50: 100%|██████████| 1875/1875 [00:04<00:00, 467.37batch/s, loss_1=0.764, loss_2=0.637]
# Epoch 50/50: 100%|██████████| 1875/1875 [00:04<00:00, 465.57batch/s, loss_1=0.978, loss_2=0.85]
# ====================================Finish training====================================

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# Loss-Epoch Diagram

# %%
plt.rcParams["text.usetex"] = True
Loss_Epoch_Diagram = LOSS_EPOCH_DIAGRAM_TWO_LOSS(
    LOSS_HISTORY_TUPLE=(
        Loss_1_Training_History,
        Loss_1_Validation_History,
        Loss_2_Training_History,
        Loss_2_Validation_History,
    ),
    CONFIG=config,
)

# %% [markdown]
# Final loss.

# %%
Loss_2_Validation_History[-1]
# Out:
# 0.9408675688506882

# %% [markdown]
# Linear Mapping Matrix Visualization.

# %%
data_temp = Net.LinearMapping.weight.detach().to("cpu").numpy()
Linear_Mapping_Weight = VISUALIZE_MATRIX(
    data_temp, config["VISUALIZATION"]["LINEAR_MAPPING_WEIGHT"], "Linear Mapping Weight"
)

# %% [markdown]
# Linear Layer Weight Visualization.

# %%
NN_Weight = VISUALIZE_NN(Net.NN, config["VISUALIZATION"]["NN_WEIGHT"])

# %% [markdown]
# ## 4. Error on Test Data

# %% [markdown]
# Test Data

# %%
test_input_data = []
test_output_data = []
for data in TestLoader:
    test_input_data += data[0].detach().to(GET_DEVICE(config["TRAIN"]["DEVICE"]))
    test_output_data += data[1].detach().to("cpu")

test_output_fromData = torch.stack(test_output_data).numpy()

# %% [markdown]
# Obtain output computed from model.

# %%
Net.eval()
test_ouput_fromModel = (
    torch.stack([Net(test_input) for test_input in test_input_data])
    .to("cpu")
    .detach()
    .numpy()
)

# %% [markdown]
# Compute standard deviation and extreme error of each element.

# %%
import itertools

StandardDeviation = np.zeros((1, test_ouput_fromModel.shape[1]))
ExtremeError = test_ouput_fromModel[:2, :] - test_output_fromData[:2, :]
for i, j in itertools.product(
    range(test_ouput_fromModel.shape[0]), range(test_ouput_fromModel.shape[1])
):
    StandardDeviation[:, j] += np.power(
        test_ouput_fromModel[i, j] - test_output_fromData[i, j], 2
    )
    ExtremeError[0, j] = max(
        ExtremeError[0, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
    ExtremeError[1, j] = min(
        ExtremeError[1, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
StandardDeviation = np.sqrt(StandardDeviation) / test_ouput_fromModel.shape[0]
StandardDeviation = StandardDeviation.reshape(
    -1,
).tolist()
UpperError = ExtremeError[0, :].tolist()
LowerError = ExtremeError[1, :].tolist()

# %% [markdown]
# Visualization.

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Standard Deviation
axs[0].bar(np.arange(len(StandardDeviation)) + 1, StandardDeviation, zorder=5)
for i in range(len(StandardDeviation)):
    axs[0].text(
        i + 1,
        StandardDeviation[i],
        "{:.4f}".format(StandardDeviation[i]),
        ha="center",
        va="bottom",
        zorder=1,
    )
axs[0].set_xticks(np.arange(len(StandardDeviation)) + 1)
axs[0].set_xlim([1 - 0.8, len(StandardDeviation) + 0.8])
axs[0].set_title("Standard Deviation of MLP with Linear Embedding", fontsize=20)
axs[0].set_xlabel("Term", fontsize=15)
axs[0].set_ylabel("Standard Deviation", fontsize=15)
axs[0].grid(axis="y", linestyle="--", zorder=0)


# Upper Error
axs[1].bar(np.arange(len(UpperError)) + 1, UpperError, zorder=5)
# Lower Error
axs[1].bar(np.arange(len(LowerError)) + 1, LowerError, zorder=5)
for i in range(len(UpperError)):
    axs[1].text(
        i + 1,
        UpperError[i],
        "{:.4f}".format(UpperError[i]),
        ha="center",
        va="bottom",
        zorder=1,
    )
    axs[1].text(
        i + 1,
        LowerError[i],
        "{:.4f}".format(LowerError[i]),
        ha="center",
        va="top",
        zorder=1,
    )
axs[1].set_xticks(np.arange(len(UpperError)) + 1)
axs[1].set_xlim([1 - 0.8, len(UpperError) + 0.8])
axs[1].set_title("Extreme Error of MLP with Linear Embedding", fontsize=20)
axs[1].set_xlabel("Term", fontsize=15)
axs[1].set_ylabel("Min/Max Error", fontsize=15)
axs[1].grid(axis="y", linestyle="--", zorder=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram of dominating error terms.

# %%
HistedTermIndex = [4, 5, 11, 12]
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for i in range(4):
    axs[int(np.floor(i / 2)), np.mod(i, 2)].hist(
        test_ouput_fromModel[:, HistedTermIndex[i]]
        - test_output_fromData[:, HistedTermIndex[i]],
        bins=50,
    )
    axs[int(np.floor(i / 2)), np.mod(i, 2)].set_xlabel("Error", fontsize=15)
    axs[int(np.floor(i / 2)), np.mod(i, 2)].set_title(
        "Error Histogram of Term {}".format(HistedTermIndex[i]), fontsize=20
    )

plt.tight_layout()
plt.show()
