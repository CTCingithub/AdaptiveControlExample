# %% [markdown]
# # Linear Embedding MLP Network with Hadamard Layer

# %% [markdown]
# ## 1. Pretreatment

# %% [markdown]
# Read data from `.mat` files.

# %%
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import yaml

import torch
import torch.nn as nn
from torchinfo import summary

with open("./config/HL_LE_MLP.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# Import data.

# %%
InputData = sp.io.loadmat(config["DATA_LOADER"]["INPUT_DATA_PATH"])
InputData = torch.from_numpy(InputData["KinematicsData"])
OutputData = sp.io.loadmat(config["DATA_LOADER"]["OUTPUT_DATA_PATH"])
OutputData = torch.from_numpy(OutputData["DynRegData"])

# %% [markdown]
# Import `NN_utils` and `Visualization`.

# %%
import sys

sys.path.append("../utils")
from NN_utils import *
from Visualization import *

SETUP_SEED(42)
torch.set_default_dtype(torch.float64)

# %% [markdown]
# Size of input and output data.

# %%
InputData.shape, OutputData.shape
# Out:
# (torch.Size([50000, 8]), torch.Size([50000, 14]))

# %% [markdown]
# Create **Training**, **Validation** and **Test** datasets.

# %%
TrainingLoader, ValidationLoader, TestLoader = Split2Loaders(
    InputData, OutputData, config
)

# %% [markdown]
# ## 2. Training

# %% [markdown]
# Define MLP network structure.

# %%
class DynReg_MLP(nn.Module):
    def __init__(self, input_size, output_size, embedding_size, hidden_size=None):
        if hidden_size is None:
            hidden_size = [16, 32, 16]
        super().__init__()

        # Linear Layer List
        self.NN = nn.ModuleList()

        self.NNStruct = [input_size] + hidden_size + [embedding_size]
        for i in range(len(self.NNStruct) - 1):
            self.NN.append(nn.Linear(self.NNStruct[i], self.NNStruct[i + 1]))

        self.hadamard = nn.Parameter(
            torch.ones(
                embedding_size,
            ),
            requires_grad=True,
        )

        self.LinearMapping = nn.Linear(embedding_size, output_size, bias=False)

    def forward(self, x):
        Output = x
        for layer in self.NN:
            Output = layer(Output)
            Output = torch.relu(Output)
        Output = self.hadamard * Output
        return self.LinearMapping(Output)

# %% [markdown]
# Define network.

# %%
Net = DynReg_MLP(
    input_size=config["NETWORK"]["INPUT_SIZE"],
    output_size=config["NETWORK"]["OUTPUT_SIZE"],
    embedding_size=config["NETWORK"]["EMBEDDING_SIZE"],
    hidden_size=config["NETWORK"]["HIDDEN_SIZE"],
)
summary(
    Net,
    input_data=torch.zeros(1, InputData.shape[1]),
    device=GET_DEVICE(),
    col_names=["input_size", "output_size", "num_params"],
    col_width=15,
)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                   Input Shape     Output Shape    Param #
# =====================================================================================
# DynReg_MLP                               [1, 8]          [1, 14]         8
# ├─ModuleList: 1-1                        --              --              --
# │    └─Linear: 2-1                       [1, 8]          [1, 16]         144
# │    └─Linear: 2-2                       [1, 16]         [1, 32]         544
# │    └─Linear: 2-3                       [1, 32]         [1, 32]         1,056
# │    └─Linear: 2-4                       [1, 32]         [1, 8]          264
# ├─Linear: 1-2                            [1, 8]          [1, 14]         112
# =====================================================================================
# Total params: 2,128
# Trainable params: 2,128
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# =====================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.02
# =====================================================================================

# %% [markdown]
# Define loss function.

# %%
def SparityLoss(SparityPromotingLayer, OutputFromNet, OutputFromData):
    sparity_loss = 0
    for layer in SparityPromotingLayer:
        for _, param in layer.named_parameters():
            sparity_loss += torch.abs(param).sum()

    return sparity_loss

# %% [markdown]
# Define optimizer.

# %%
optimizer = torch.optim.Adam(
    Net.parameters(),
    lr=config["TRAIN"]["LEARNING_RATE"],
    weight_decay=config["TRAIN"]["WEIGHT_DECAY"],
)

# %% [markdown]
# Training network.

# %%
(
    Loss_1_Training_History,
    Loss_1_Validation_History,
    Loss_2_Training_History,
    Loss_2_Validation_History,
) = TRAIN_WITH_PROGRESS_BAR_TWO_LOSS(
    MODEL=Net,
    CONFIG=config,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=TrainingLoader,
    VALIDATION_LOADER=ValidationLoader,
    LOSS_TUPLE=[
        nn.MSELoss(),
        lambda y1, y2: SparityLoss(
            [
                Net.LinearMapping,
            ],
            y1,
            y2,
        ),
    ],
    FREEZE_LAYER=[
        Net.LinearMapping,
    ],
)
# Out:
# PyTorch Version: 2.2.2
# Weight initialized with Kaiming Initialization
# Training on cpu
# ====================================Start training====================================
# Epoch 1/50: 100%|██████████| 1875/1875 [00:04<00:00, 413.38batch/s, loss_1=28.3, loss_2=28.2]
# Epoch 2/50: 100%|██████████| 1875/1875 [00:04<00:00, 403.10batch/s, loss_1=22.3, loss_2=22.2]
# Epoch 3/50: 100%|██████████| 1875/1875 [00:04<00:00, 410.97batch/s, loss_1=9.89, loss_2=9.76]
# Epoch 4/50: 100%|██████████| 1875/1875 [00:04<00:00, 409.68batch/s, loss_1=6.71, loss_2=6.57]
# Epoch 5/50: 100%|██████████| 1875/1875 [00:04<00:00, 381.00batch/s, loss_1=4, loss_2=3.85]
# Epoch 6/50: 100%|██████████| 1875/1875 [00:05<00:00, 374.53batch/s, loss_1=3.51, loss_2=3.35]
# Epoch 7/50: 100%|██████████| 1875/1875 [00:04<00:00, 380.06batch/s, loss_1=3.21, loss_2=3.05]
# Epoch 8/50: 100%|██████████| 1875/1875 [00:05<00:00, 372.87batch/s, loss_1=3.68, loss_2=3.52]
# Epoch 9/50: 100%|██████████| 1875/1875 [00:04<00:00, 391.27batch/s, loss_1=2.55, loss_2=2.39]
# Epoch 10/50: 100%|██████████| 1875/1875 [00:04<00:00, 384.46batch/s, loss_1=2.93, loss_2=2.77]
# Epoch 11/50: 100%|██████████| 1875/1875 [00:04<00:00, 419.96batch/s, loss_1=3.28, loss_2=3.12]
# Epoch 12/50: 100%|██████████| 1875/1875 [00:05<00:00, 369.87batch/s, loss_1=3.19, loss_2=3.02]
# Epoch 13/50: 100%|██████████| 1875/1875 [00:05<00:00, 362.51batch/s, loss_1=2.07, loss_2=1.91]
# Epoch 14/50: 100%|██████████| 1875/1875 [00:05<00:00, 365.84batch/s, loss_1=2.61, loss_2=2.45]
# Epoch 15/50: 100%|██████████| 1875/1875 [00:05<00:00, 366.98batch/s, loss_1=2.84, loss_2=2.69]
# Epoch 16/50: 100%|██████████| 1875/1875 [00:05<00:00, 365.10batch/s, loss_1=2.42, loss_2=2.27]
# Epoch 17/50: 100%|██████████| 1875/1875 [00:04<00:00, 393.72batch/s, loss_1=2.52, loss_2=2.37]
# Epoch 18/50: 100%|██████████| 1875/1875 [00:04<00:00, 383.72batch/s, loss_1=2.75, loss_2=2.6]
# Epoch 19/50: 100%|██████████| 1875/1875 [00:04<00:00, 379.50batch/s, loss_1=1.34, loss_2=1.19]
# Epoch 20/50: 100%|██████████| 1875/1875 [00:05<00:00, 342.32batch/s, loss_1=2.54, loss_2=2.39]
# Epoch 21/50: 100%|██████████| 1875/1875 [00:05<00:00, 337.18batch/s, loss_1=2.51, loss_2=2.37]
# Epoch 22/50: 100%|██████████| 1875/1875 [00:05<00:00, 345.40batch/s, loss_1=2.18, loss_2=2.04]
# Epoch 23/50: 100%|██████████| 1875/1875 [00:06<00:00, 292.90batch/s, loss_1=2.09, loss_2=1.95]
# Epoch 24/50: 100%|██████████| 1875/1875 [00:06<00:00, 286.63batch/s, loss_1=2.46, loss_2=2.33]
# Epoch 25/50: 100%|██████████| 1875/1875 [00:06<00:00, 295.07batch/s, loss_1=2.55, loss_2=2.41]
# Epoch 26/50: 100%|██████████| 1875/1875 [00:05<00:00, 364.93batch/s, loss_1=2.14, loss_2=2.01]
# Epoch 27/50: 100%|██████████| 1875/1875 [00:05<00:00, 365.38batch/s, loss_1=2.59, loss_2=2.46]
# Epoch 28/50: 100%|██████████| 1875/1875 [00:04<00:00, 377.95batch/s, loss_1=2.22, loss_2=2.09]
# Epoch 29/50: 100%|██████████| 1875/1875 [00:04<00:00, 385.17batch/s, loss_1=2.59, loss_2=2.46]
# Epoch 30/50: 100%|██████████| 1875/1875 [00:04<00:00, 385.69batch/s, loss_1=1.93, loss_2=1.8]
# Epoch 31/50: 100%|██████████| 1875/1875 [00:04<00:00, 383.50batch/s, loss_1=2.38, loss_2=2.25]
# Epoch 32/50: 100%|██████████| 1875/1875 [00:04<00:00, 379.42batch/s, loss_1=1.8, loss_2=1.67]
# Epoch 33/50: 100%|██████████| 1875/1875 [00:05<00:00, 369.15batch/s, loss_1=2.21, loss_2=2.09]
# Epoch 34/50: 100%|██████████| 1875/1875 [00:05<00:00, 340.50batch/s, loss_1=1.86, loss_2=1.73]
# Epoch 35/50: 100%|██████████| 1875/1875 [00:05<00:00, 363.11batch/s, loss_1=3.18, loss_2=3.06]
# Epoch 36/50: 100%|██████████| 1875/1875 [00:04<00:00, 384.25batch/s, loss_1=2.41, loss_2=2.29]
# Epoch 37/50: 100%|██████████| 1875/1875 [00:05<00:00, 366.02batch/s, loss_1=1.6, loss_2=1.48]
# Epoch 38/50: 100%|██████████| 1875/1875 [00:05<00:00, 340.33batch/s, loss_1=2.88, loss_2=2.76]
# Epoch 39/50: 100%|██████████| 1875/1875 [00:06<00:00, 285.87batch/s, loss_1=2.17, loss_2=2.05]
# Epoch 40/50: 100%|██████████| 1875/1875 [00:05<00:00, 371.31batch/s, loss_1=2, loss_2=1.88]
# Epoch 41/50: 100%|██████████| 1875/1875 [00:04<00:00, 398.49batch/s, loss_1=2.02, loss_2=1.9]
# Epoch 42/50: 100%|██████████| 1875/1875 [00:04<00:00, 387.80batch/s, loss_1=1.74, loss_2=1.62]
# Epoch 43/50: 100%|██████████| 1875/1875 [00:04<00:00, 397.21batch/s, loss_1=1.21, loss_2=1.09]
# Epoch 44/50: 100%|██████████| 1875/1875 [00:04<00:00, 409.49batch/s, loss_1=1.74, loss_2=1.63]
# Epoch 45/50: 100%|██████████| 1875/1875 [00:04<00:00, 412.92batch/s, loss_1=1.02, loss_2=0.908]
# Epoch 46/50: 100%|██████████| 1875/1875 [00:04<00:00, 404.62batch/s, loss_1=1.23, loss_2=1.12]
# Epoch 47/50: 100%|██████████| 1875/1875 [00:04<00:00, 383.23batch/s, loss_1=1.68, loss_2=1.57]
# Epoch 48/50: 100%|██████████| 1875/1875 [00:04<00:00, 387.73batch/s, loss_1=1.27, loss_2=1.16]
# Epoch 49/50: 100%|██████████| 1875/1875 [00:05<00:00, 357.72batch/s, loss_1=1.53, loss_2=1.42]
# Epoch 50/50: 100%|██████████| 1875/1875 [00:04<00:00, 393.09batch/s, loss_1=1.38, loss_2=1.28]
# ====================================Finish training====================================

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# Loss-Epoch Diagram

# %%
plt.rcParams["text.usetex"] = True
Loss_Epoch_Diagram = LOSS_EPOCH_DIAGRAM_TWO_LOSS(
    LOSS_HISTORY_TUPLE=(
        Loss_1_Training_History,
        Loss_1_Validation_History,
        Loss_2_Training_History,
        Loss_2_Validation_History,
    ),
    CONFIG=config,
)

# %% [markdown]
# Final loss.

# %%
Loss_2_Validation_History[-1]
# Out:
# 1.4686317203628947

# %% [markdown]
# Linear Mapping Matrix Visualization.

# %%
data_temp = Net.LinearMapping.weight.detach().to("cpu").numpy()
Linear_Mapping_Weight = VISUALIZE_MATRIX(
    data_temp, config["VISUALIZATION"]["LINEAR_MAPPING_WEIGHT"], "Linear Mapping Weight"
)

# %% [markdown]
# Hadmard Layer Visualization.

# %%
plt.bar(
    np.arange(1, config["NETWORK"]["EMBEDDING_SIZE"] + 1),
    Net.hadamard.detach().to("cpu").numpy(),
)
plt.title("Hadamard Layer Weight", fontsize=20)
plt.show()

# %% [markdown]
# Linear Layer Weight Visualization.

# %%
NN_Weight = VISUALIZE_NN(Net.NN, config["VISUALIZATION"]["NN_WEIGHT"])

# %% [markdown]
# ## 4. Error on Test Data

# %% [markdown]
# Test Data

# %%
test_input_data = []
test_output_data = []
for data in TestLoader:
    test_input_data += data[0].detach().to(GET_DEVICE(config["TRAIN"]["DEVICE"]))
    test_output_data += data[1].detach().to("cpu")

test_output_fromData = torch.stack(test_output_data).numpy()

# %% [markdown]
# Obtain output computed from model.

# %%
Net.eval()
test_ouput_fromModel = (
    torch.stack([Net(test_input) for test_input in test_input_data])
    .to("cpu")
    .detach()
    .numpy()
)

# %% [markdown]
# Compute standard deviation and extreme error of each element.

# %%
import itertools

StandardDeviation = np.zeros((1, test_ouput_fromModel.shape[1]))
ExtremeError = test_ouput_fromModel[:2, :] - test_output_fromData[:2, :]
for i, j in itertools.product(
    range(test_ouput_fromModel.shape[0]), range(test_ouput_fromModel.shape[1])
):
    StandardDeviation[:, j] += np.power(
        test_ouput_fromModel[i, j] - test_output_fromData[i, j], 2
    )
    ExtremeError[0, j] = max(
        ExtremeError[0, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
    ExtremeError[1, j] = min(
        ExtremeError[1, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
StandardDeviation = np.sqrt(StandardDeviation) / test_ouput_fromModel.shape[0]
StandardDeviation = StandardDeviation.reshape(
    -1,
).tolist()
UpperError = ExtremeError[0, :].tolist()
LowerError = ExtremeError[1, :].tolist()

# %% [markdown]
# Visualization.

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Standard Deviation
axs[0].bar(np.arange(len(StandardDeviation)) + 1, StandardDeviation, zorder=5)
for i in range(len(StandardDeviation)):
    axs[0].text(
        i + 1,
        StandardDeviation[i],
        "{:.4f}".format(StandardDeviation[i]),
        ha="center",
        va="bottom",
        zorder=1,
    )
axs[0].set_xticks(np.arange(len(StandardDeviation)) + 1)
axs[0].set_xlim([1 - 0.8, len(StandardDeviation) + 0.8])
axs[0].set_title("Standard Deviation of MLP with Linear Embedding", fontsize=20)
axs[0].set_xlabel("Term", fontsize=15)
axs[0].set_ylabel("Standard Deviation", fontsize=15)
axs[0].grid(axis="y", linestyle="--", zorder=0)


# Upper Error
axs[1].bar(np.arange(len(UpperError)) + 1, UpperError, zorder=5)
# Lower Error
axs[1].bar(np.arange(len(LowerError)) + 1, LowerError, zorder=5)
for i in range(len(UpperError)):
    axs[1].text(
        i + 1,
        UpperError[i],
        "{:.4f}".format(UpperError[i]),
        ha="center",
        va="bottom",
        zorder=1,
    )
    axs[1].text(
        i + 1,
        LowerError[i],
        "{:.4f}".format(LowerError[i]),
        ha="center",
        va="top",
        zorder=1,
    )
axs[1].set_xticks(np.arange(len(UpperError)) + 1)
axs[1].set_xlim([1 - 0.8, len(UpperError) + 0.8])
axs[1].set_title("Extreme Error of MLP with Linear Embedding", fontsize=20)
axs[1].set_xlabel("Term", fontsize=15)
axs[1].set_ylabel("Min/Max Error", fontsize=15)
axs[1].grid(axis="y", linestyle="--", zorder=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram of dominating error terms.

# %%
HistedTermIndex = [4, 5, 11, 12]
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for i in range(4):
    axs[int(np.floor(i / 2)), np.mod(i, 2)].hist(
        test_ouput_fromModel[:, HistedTermIndex[i]]
        - test_output_fromData[:, HistedTermIndex[i]],
        bins=50,
    )
    axs[int(np.floor(i / 2)), np.mod(i, 2)].set_xlabel("Error", fontsize=15)
    axs[int(np.floor(i / 2)), np.mod(i, 2)].set_title(
        "Error Histogram of Term {}".format(HistedTermIndex[i]), fontsize=20
    )

plt.tight_layout()
plt.show()
