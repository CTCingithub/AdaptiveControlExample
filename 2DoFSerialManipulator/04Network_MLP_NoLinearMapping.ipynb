# %% [markdown]
# # MLP Network

# %% [markdown]
# ## 1. Pretreatment

# %% [markdown]
# Read data from `.mat` files.

# %%
import scipy as sp
import torch
import torch.nn as nn
from torchinfo import summary

torch.set_default_dtype(torch.float64)
Input = sp.io.loadmat("Data/KinematicsData.mat")
Input = torch.from_numpy(Input["KinematicsData"])
Output = sp.io.loadmat("Data/DynRegVecData.mat")
Output = torch.from_numpy(Output["DynRegData"])

# %% [markdown]
# Size of input and output data.

# %%
Input.shape, Output.shape
# Out:
# (torch.Size([50000, 6]), torch.Size([50000, 14]))

# %% [markdown]
# import `utils` module.

# %%
import sys

sys.path.append("..")
from utils import *

# %% [markdown]
# Create **Training** and **Validation** datasets.

# %%
TrainingLoader, ValidationLoader = Split2Loaders(
    Input, Output, BATCHSIZE=32, RATIO=0.8, SHUFFLE=True
)

# %% [markdown]
# ## 2. Training

# %% [markdown]
# Define MLP network structure.

# %%
class DynReg_MLP(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=None):
        if hidden_size is None:
            hidden_size = [16, 32, 16]
        super().__init__()

        # 创建一个线性层的列表
        self.layers = nn.ModuleList()

        self.LinearLayerStruct = [input_size] + hidden_size + [output_size]

        for i in range(len(self.LinearLayerStruct) - 1):
            self.layers.append(
                nn.Linear(self.LinearLayerStruct[i], self.LinearLayerStruct[i + 1])
            )

    def forward(self, x):
        Output = x
        for layer in self.layers:
            Output = layer(Output)
            Output = torch.relu(Output)
        return Output

# %% [markdown]
# Define network.

# %%
Net = DynReg_MLP(
    input_size=Input.shape[1], output_size=Output.shape[1], hidden_size=[32, 64, 64]
)
summary(
    Net,
    input_data=torch.zeros(1, Input.shape[1]),
    device=GET_DEVICE(),
    col_names=["input_size", "output_size", "num_params"],
    col_width=15,
)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                   Input Shape     Output Shape    Param #
# =====================================================================================
# DynReg_MLP                               [1, 6]          [1, 14]         --
# ├─ModuleList: 1-1                        --              --              --
# │    └─Linear: 2-1                       [1, 6]          [1, 32]         224
# │    └─Linear: 2-2                       [1, 32]         [1, 64]         2,112
# │    └─Linear: 2-3                       [1, 64]         [1, 64]         4,160
# │    └─Linear: 2-4                       [1, 64]         [1, 14]         910
# =====================================================================================
# Total params: 7,406
# Trainable params: 7,406
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# =====================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.06
# =====================================================================================

# %% [markdown]
# Define optimizer.

# %%
optimizer = torch.optim.Adam(Net.parameters(), lr=0.001, weight_decay=0)

# %% [markdown]
# Initialize weight.

# %%
INIT_WEIGHTS_XAVIER(Net)

# %% [markdown]
# Define training configuration.

# %%
num_epochs = 20

# %% [markdown]
# Training network.

# %%
(
    Loss_Training_History,
    Loss_Validation_History,
) = TRAIN_WITH_PROGRESS_BAR_ONE_LOSS(
    MODEL=Net,
    NUM_EPOCHS=num_epochs,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=TrainingLoader,
    VALIDATION_LOADER=ValidationLoader,
    LOSS_TYPE=nn.MSELoss(),
    DEVICE=0,
)
# Out:
# PyTorch Version: 2.2.2
# Training on cuda:0
# ====================================Start training====================================
# Epoch 1/20: 100%|██████████| 1250/1250 [00:03<00:00, 346.03batch/s, loss=35.5]
# Epoch 2/20: 100%|██████████| 1250/1250 [00:04<00:00, 302.37batch/s, loss=24.6]
# Epoch 3/20: 100%|██████████| 1250/1250 [00:03<00:00, 322.35batch/s, loss=34.5]
# Epoch 4/20: 100%|██████████| 1250/1250 [00:04<00:00, 310.92batch/s, loss=39.2]
# Epoch 5/20: 100%|██████████| 1250/1250 [00:03<00:00, 319.53batch/s, loss=27.8]
# Epoch 6/20: 100%|██████████| 1250/1250 [00:03<00:00, 320.33batch/s, loss=30.4]
# Epoch 7/20: 100%|██████████| 1250/1250 [00:04<00:00, 306.42batch/s, loss=17.9]
# Epoch 8/20: 100%|██████████| 1250/1250 [00:04<00:00, 292.11batch/s, loss=28.8]
# Epoch 9/20: 100%|██████████| 1250/1250 [00:04<00:00, 294.12batch/s, loss=26.7]
# Epoch 10/20: 100%|██████████| 1250/1250 [00:03<00:00, 312.74batch/s, loss=21]
# Epoch 11/20: 100%|██████████| 1250/1250 [00:04<00:00, 294.87batch/s, loss=29.5]
# Epoch 12/20: 100%|██████████| 1250/1250 [00:04<00:00, 311.03batch/s, loss=26]
# Epoch 13/20: 100%|██████████| 1250/1250 [00:03<00:00, 318.73batch/s, loss=27.4]
# Epoch 14/20: 100%|██████████| 1250/1250 [00:04<00:00, 306.00batch/s, loss=23.2]
# Epoch 15/20: 100%|██████████| 1250/1250 [00:03<00:00, 325.69batch/s, loss=28.4]
# Epoch 16/20: 100%|██████████| 1250/1250 [00:03<00:00, 316.35batch/s, loss=23.3]
# Epoch 17/20: 100%|██████████| 1250/1250 [00:03<00:00, 335.36batch/s, loss=30.2]
# Epoch 18/20: 100%|██████████| 1250/1250 [00:03<00:00, 324.14batch/s, loss=21.6]
# Epoch 19/20: 100%|██████████| 1250/1250 [00:03<00:00, 335.16batch/s, loss=28.4]
# Epoch 20/20: 100%|██████████| 1250/1250 [00:03<00:00, 327.83batch/s, loss=22.9]
# ====================================Finish training====================================

# %% [markdown]
# Visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["text.usetex"] = True
x_axis_segments = 10

plt.plot(
    np.arange(0, len(Loss_Training_History)),
    Loss_Training_History,
    label="Training Loss",
)
plt.plot(
    np.arange(0, len(Loss_Validation_History)),
    Loss_Validation_History,
    label="Validation Loss",
)
plt.title("Loss with Sparsity")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xticks(np.linspace(0, num_epochs, x_axis_segments + 1, dtype=int))
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# Final loss.

# %%
Loss_Validation_History[-1]
# Out:
# tensor(26.5328)

# %% [markdown]
# Linear Layer Weight Visualization.

# %%
fig, ax = plt.subplots(
    1, len(Net.layers), figsize=(3 * len(Net.layers) + 1, 3), dpi=100
)

for index, layer in enumerate(Net.layers):
    CurrentPlot = ax[index].pcolor(
        layer.weight.detach().to("cpu").numpy(), cmap="gist_heat"
    )
    ax[index].invert_yaxis()
    ax[index].set_title(f"Layer {str(index + 1)}", fontsize=15)
    plt.colorbar(CurrentPlot, ax=ax[index])
    if index == 0:
        ax[index].set_xticks([2, 4, 6])
        ax[index].set_xticklabels([r"$r_i$", r"$v_i$", r"$a_i$"])
plt.tight_layout()
