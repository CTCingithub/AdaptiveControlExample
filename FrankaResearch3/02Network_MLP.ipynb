# %% [markdown]
# # MLP Network

# %% [markdown]
# ## 1. Pretreatment

# %% [markdown]
# Import Configuration.

# %%
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import yaml

import torch
import torch.nn as nn
from torchinfo import summary

with open("./config/MLP.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# Import data.

# %%
InputData = sp.io.loadmat(config["DATA_LOADER"]["INPUT_DATA_PATH"])
InputData = torch.from_numpy(InputData["KinematicsData"])
OutputData = sp.io.loadmat(config["DATA_LOADER"]["OUTPUT_DATA_PATH"])
OutputData = torch.from_numpy(OutputData["DynRegVecData"])

# %% [markdown]
# Import `NN_utils` and `Visualization`.

# %%
import sys

sys.path.append("../utils")
from NN_utils import *
from Visualization import *

SETUP_SEED(42)
torch.set_default_dtype(torch.float64)

# %% [markdown]
# Size of input and output data.

# %%
InputData.shape, OutputData.shape
# Out:
# (torch.Size([50000, 28]), torch.Size([50000, 413]))

# %% [markdown]
# Create **Training**, **Validation** and **Test** datasets.

# %%
TrainingLoader, ValidationLoader, TestLoader = Split2Loaders(
    InputData, OutputData, config
)

# %% [markdown]
# ## 2. Training

# %% [markdown]
# Define MLP network structure.

# %%
class DynReg_MLP(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=None):
        if hidden_size is None:
            hidden_size = [16, 32, 16]
        super().__init__()

        # Linear Layer List
        self.NN = nn.ModuleList()

        self.NNStruct = [input_size] + hidden_size + [output_size]

        for i in range(len(self.NNStruct) - 1):
            self.NN.append(
                nn.Linear(self.NNStruct[i], self.NNStruct[i + 1])
            )

    def forward(self, x):
        Output = x
        for layer in self.NN:
            Output = layer(Output)
            if layer != self.NN[-1]:
                Output = torch.relu(Output)
        return Output

# %% [markdown]
# Define network.

# %%
Net = DynReg_MLP(
    input_size=config["NETWORK"]["INPUT_SIZE"],
    output_size=config["NETWORK"]["OUTPUT_SIZE"],
    hidden_size=config["NETWORK"]["HIDDEN_SIZE"],
)
summary(
    Net,
    input_data=torch.zeros(1, InputData.shape[1]),
    device=GET_DEVICE(),
    col_names=["input_size", "output_size", "num_params"],
    col_width=15,
)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                   Input Shape     Output Shape    Param #
# =====================================================================================
# DynReg_MLP                               [1, 28]         [1, 413]        --
# ├─ModuleList: 1-1                        --              --              --
# │    └─Linear: 2-1                       [1, 28]         [1, 128]        3,712
# │    └─Linear: 2-2                       [1, 128]        [1, 256]        33,024
# │    └─Linear: 2-3                       [1, 256]        [1, 512]        131,584
# │    └─Linear: 2-4                       [1, 512]        [1, 413]        211,869
# =====================================================================================
# Total params: 380,189
# Trainable params: 380,189
# Non-trainable params: 0
# Total mult-adds (M): 0.38
# =====================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 3.04
# Estimated Total Size (MB): 3.06
# =====================================================================================

# %% [markdown]
# Define optimizer.

# %%
optimizer = torch.optim.Adam(
    Net.parameters(),
    lr=config["TRAIN"]["LEARNING_RATE"],
    weight_decay=config["TRAIN"]["WEIGHT_DECAY"],
)

# %% [markdown]
# Training network.

# %%
(
    Loss_Training_History,
    Loss_Validation_History,
) = TRAIN_WITH_PROGRESS_BAR_ONE_LOSS(
    MODEL=Net,
    CONFIG=config,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=TrainingLoader,
    VALIDATION_LOADER=ValidationLoader,
    LOSS_TYPE=nn.MSELoss(),
)
# Out:
# PyTorch Version: 2.2.2
# Weight initialized with Kaiming Initialization
# Training on cuda:0
# ====================================Start training====================================
# Epoch 1/30: 100%|██████████| 1875/1875 [00:09<00:00, 206.11batch/s, loss=4.72e+3]
# Epoch 2/30: 100%|██████████| 1875/1875 [00:08<00:00, 217.11batch/s, loss=3.96e+3]
# Epoch 3/30: 100%|██████████| 1875/1875 [00:08<00:00, 228.81batch/s, loss=3.63e+3]
# Epoch 4/30: 100%|██████████| 1875/1875 [00:07<00:00, 251.39batch/s, loss=4.9e+3]
# Epoch 5/30: 100%|██████████| 1875/1875 [00:09<00:00, 206.40batch/s, loss=4.88e+3]
# Epoch 6/30: 100%|██████████| 1875/1875 [00:09<00:00, 195.25batch/s, loss=5.74e+3]
# Epoch 7/30: 100%|██████████| 1875/1875 [00:08<00:00, 208.37batch/s, loss=4.52e+3]
# Epoch 8/30: 100%|██████████| 1875/1875 [00:09<00:00, 190.27batch/s, loss=4.75e+3]
# Epoch 9/30: 100%|██████████| 1875/1875 [00:09<00:00, 205.48batch/s, loss=4.31e+3]
# Epoch 10/30: 100%|██████████| 1875/1875 [00:09<00:00, 203.73batch/s, loss=3.75e+3]
# Epoch 11/30: 100%|██████████| 1875/1875 [00:08<00:00, 218.89batch/s, loss=4.74e+3]
# Epoch 12/30: 100%|██████████| 1875/1875 [00:09<00:00, 205.42batch/s, loss=3.56e+3]
# Epoch 13/30: 100%|██████████| 1875/1875 [00:08<00:00, 216.71batch/s, loss=3.33e+3]
# Epoch 14/30: 100%|██████████| 1875/1875 [00:08<00:00, 215.00batch/s, loss=3.94e+3]
# Epoch 15/30: 100%|██████████| 1875/1875 [00:08<00:00, 217.93batch/s, loss=3.96e+3]
# Epoch 16/30: 100%|██████████| 1875/1875 [00:08<00:00, 218.87batch/s, loss=4.17e+3]
# Epoch 17/30: 100%|██████████| 1875/1875 [00:08<00:00, 220.01batch/s, loss=5.24e+3]
# Epoch 18/30: 100%|██████████| 1875/1875 [00:08<00:00, 216.90batch/s, loss=3.22e+3]
# Epoch 19/30: 100%|██████████| 1875/1875 [00:08<00:00, 220.82batch/s, loss=4.55e+3]
# Epoch 20/30: 100%|██████████| 1875/1875 [00:08<00:00, 212.75batch/s, loss=3.52e+3]
# Epoch 21/30: 100%|██████████| 1875/1875 [00:08<00:00, 215.81batch/s, loss=3.65e+3]
# Epoch 22/30: 100%|██████████| 1875/1875 [00:08<00:00, 214.19batch/s, loss=5.22e+3]
# Epoch 23/30: 100%|██████████| 1875/1875 [00:08<00:00, 215.19batch/s, loss=4.8e+3]
# Epoch 24/30: 100%|██████████| 1875/1875 [00:08<00:00, 211.78batch/s, loss=4.09e+3]
# Epoch 25/30: 100%|██████████| 1875/1875 [00:08<00:00, 211.98batch/s, loss=3.13e+3]
# Epoch 26/30: 100%|██████████| 1875/1875 [00:08<00:00, 216.54batch/s, loss=5.41e+3]
# Epoch 27/30: 100%|██████████| 1875/1875 [00:08<00:00, 218.27batch/s, loss=4.7e+3]
# Epoch 28/30: 100%|██████████| 1875/1875 [00:08<00:00, 218.10batch/s, loss=3.99e+3]
# Epoch 29/30: 100%|██████████| 1875/1875 [00:08<00:00, 223.36batch/s, loss=4.37e+3]
# Epoch 30/30: 100%|██████████| 1875/1875 [00:07<00:00, 238.87batch/s, loss=3.81e+3]
# ====================================Finish training====================================

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# Loss-Epoch Diagram

# %%
plt.rcParams["text.usetex"] = True
Loss_Epoch_Diagram = LOSS_EPOCH_DIAGRAM_ONE_LOSS(
    LOSS_HISTORY_TUPLE=(
        Loss_Training_History,
        Loss_Validation_History,
    ),
    CONFIG=config,
)

# %% [markdown]
# Final loss.

# %%
Loss_Validation_History[-1]
# Out:
# 4262.441253949642

# %% [markdown]
# Linear Layer Weight Visualization.

# %%
NN_Weight = VISUALIZE_NN(Net.NN, config["VISUALIZATION"]["NN_WEIGHT"])

# %% [markdown]
# ## 4. Error on Test Data

# %% [markdown]
# Test Data

# %%
test_input_data = []
test_output_data = []
for data in TestLoader:
    test_input_data += data[0].detach().to(GET_DEVICE(config["TRAIN"]["DEVICE"]))
    test_output_data += data[1].detach().to("cpu")

test_output_fromData = torch.stack(test_output_data).numpy()

# %% [markdown]
# Obtain output computed from model.

# %%
Net.eval()
test_ouput_fromModel = torch.stack(
    [Net(test_input).detach().to("cpu") for test_input in test_input_data]
).numpy()

# %% [markdown]
# Compute standard deviation and extreme error of each element.

# %%
import itertools

StandardDeviation = np.zeros((1, test_ouput_fromModel.shape[1]))
ExtremeError = test_ouput_fromModel[:2, :] - test_output_fromData[:2, :]
for i, j in itertools.product(
    range(test_ouput_fromModel.shape[0]), range(test_ouput_fromModel.shape[1])
):
    StandardDeviation[:, j] += np.power(
        test_ouput_fromModel[i, j] - test_output_fromData[i, j], 2
    )
    ExtremeError[0, j] = max(
        ExtremeError[0, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
    ExtremeError[1, j] = min(
        ExtremeError[1, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
StandardDeviation = np.sqrt(StandardDeviation) / test_ouput_fromModel.shape[0]
StandardDeviation = StandardDeviation.reshape(
    -1,
).tolist()
UpperError = ExtremeError[0, :].tolist()
LowerError = ExtremeError[1, :].tolist()

# %% [markdown]
# Visualization.

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Standard Deviation
axs[0].bar(np.arange(len(StandardDeviation)) + 1, StandardDeviation, zorder=5)
axs[0].set_xticks(np.linspace(1, len(StandardDeviation) + 1, 20, dtype=int))
axs[0].set_xlim([1 - 0.8, len(StandardDeviation) + 0.8])
axs[0].set_title("Standard Deviation of MLP", fontsize=20)
axs[0].set_xlabel("Term", fontsize=15)
axs[0].set_ylabel("Standard Deviation", fontsize=15)
axs[0].grid(axis="y", linestyle="--", zorder=-1)


# Upper Error
axs[1].bar(np.arange(len(UpperError)) + 1, UpperError, zorder=5)
# Lower Error
axs[1].bar(np.arange(len(LowerError)) + 1, LowerError, zorder=5)
axs[1].set_xticks(np.linspace(1, len(StandardDeviation) + 1, 20, dtype=int))
axs[1].set_xlim([1 - 0.8, len(UpperError) + 0.8])
axs[1].set_title("Extreme Error of MLP", fontsize=20)
axs[1].set_xlabel("Term", fontsize=15)
axs[1].set_ylabel("Min/Max Error", fontsize=15)
axs[1].grid(axis="y", linestyle="--", zorder=0)

plt.tight_layout()
plt.show()
