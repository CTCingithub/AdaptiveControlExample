# %% [markdown]
# # Linear Embedding MLP Network

# %% [markdown]
# ## 1. Pretreatment

# %% [markdown]
# Import Configuration.

# %%
import scipy as sp
import matplotlib.pyplot as plt
import numpy as np
import yaml

import torch
import torch.nn as nn
from torchinfo import summary

with open("./config/LE_MLP.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# Import data.

# %%
InputData = sp.io.loadmat(config["DATA_LOADER"]["INPUT_DATA_PATH"])
InputData = torch.from_numpy(InputData["KinematicsData"])
OutputData = sp.io.loadmat(config["DATA_LOADER"]["OUTPUT_DATA_PATH"])
OutputData = torch.from_numpy(OutputData["DynRegVecData"])

# %% [markdown]
# Import `NN_utils` and `Visualization`.

# %%
import sys

sys.path.append("../utils")
from NN_utils import *
from Visualization import *

SETUP_SEED(42)
torch.set_default_dtype(torch.float64)

# %% [markdown]
# Size of input and output data.

# %%
InputData.shape, OutputData.shape
# Out:
# (torch.Size([50000, 28]), torch.Size([50000, 413]))

# %% [markdown]
# Create **Training**, **Validation** and **Test** datasets.

# %%
TrainingLoader, ValidationLoader, TestLoader = Split2Loaders(
    InputData, OutputData, config
)

# %% [markdown]
# ## 2. Training

# %% [markdown]
# Define MLP network structure.

# %%
class DynReg_MLP(nn.Module):
    def __init__(self, input_size, output_size, embedding_size, hidden_size=None):
        if hidden_size is None:
            hidden_size = [256, 256, 512]
        super().__init__()

        # Linear Layer List
        self.NN = nn.ModuleList()

        self.NNStruct = [input_size] + hidden_size + [embedding_size]
        for i in range(len(self.NNStruct) - 1):
            self.NN.append(nn.Linear(self.NNStruct[i], self.NNStruct[i + 1]))

        self.LinearMapping = nn.Linear(embedding_size, output_size, bias=False)

    def forward(self, x):
        Output = x
        for layer in self.NN:
            Output = layer(Output)
            if layer != self.NN[-1]:
                Output = torch.relu(Output)
        Output = self.LinearMapping(Output)
        return Output

# %% [markdown]
# Define network.

# %%
Net = DynReg_MLP(
    input_size=config["NETWORK"]["INPUT_SIZE"],
    output_size=config["NETWORK"]["OUTPUT_SIZE"],
    embedding_size=config["NETWORK"]["EMBEDDING_SIZE"],
    hidden_size=config["NETWORK"]["HIDDEN_SIZE"],
)
summary(
    Net,
    input_data=torch.zeros(1, InputData.shape[1]),
    device=GET_DEVICE(),
    col_names=["input_size", "output_size", "num_params"],
    col_width=15,
)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                   Input Shape     Output Shape    Param #
# =====================================================================================
# DynReg_MLP                               [1, 28]         [1, 413]        --
# ├─ModuleList: 1-1                        --              --              --
# │    └─Linear: 2-1                       [1, 28]         [1, 128]        3,712
# │    └─Linear: 2-2                       [1, 128]        [1, 256]        33,024
# │    └─Linear: 2-3                       [1, 256]        [1, 512]        131,584
# │    └─Linear: 2-4                       [1, 512]        [1, 222]        113,886
# ├─Linear: 1-2                            [1, 222]        [1, 413]        91,686
# =====================================================================================
# Total params: 373,892
# Trainable params: 373,892
# Non-trainable params: 0
# Total mult-adds (M): 0.37
# =====================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 2.99
# Estimated Total Size (MB): 3.02
# =====================================================================================

# %% [markdown]
# Define loss function.

# %%
def SparityLoss(SparityPromotingLayer, OutputFromNet, OutputFromData):
    sparity_loss = 0
    for layer in SparityPromotingLayer:
        for _, param in layer.named_parameters():
            sparity_loss += torch.abs(param).sum()

    return sparity_loss

# %% [markdown]
# Define optimizer.

# %%
optimizer = torch.optim.Adam(
    Net.parameters(),
    lr=config["TRAIN"]["LEARNING_RATE"],
    weight_decay=config["TRAIN"]["WEIGHT_DECAY"],
)

# %% [markdown]
# Training network.

# %%
(
    Loss_1_Training_History,
    Loss_1_Validation_History,
    Loss_2_Training_History,
    Loss_2_Validation_History,
) = TRAIN_WITH_PROGRESS_BAR_TWO_LOSS(
    MODEL=Net,
    CONFIG=config,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=TrainingLoader,
    VALIDATION_LOADER=ValidationLoader,
    LOSS_TUPLE=[
        nn.MSELoss(),
        lambda y1, y2: SparityLoss(
            [
                Net.LinearMapping,
            ],
            y1,
            y2,
        ),
    ],
    FREEZE_LAYER=[
        Net.LinearMapping,
    ],
)
# Out:
# PyTorch Version: 2.2.2
# Weight initialized with Kaiming Initialization
# Training on cuda:0
# ====================================Start training====================================
# Epoch 1/30: 100%|██████████| 1875/1875 [00:09<00:00, 195.21batch/s, loss_1=4.05e+3, loss_2=4.04e+3]
# Epoch 2/30: 100%|██████████| 1875/1875 [00:09<00:00, 190.33batch/s, loss_1=4.63e+3, loss_2=4.62e+3]
# Epoch 3/30: 100%|██████████| 1875/1875 [00:08<00:00, 210.46batch/s, loss_1=4.25e+3, loss_2=4.23e+3]
# Epoch 4/30: 100%|██████████| 1875/1875 [00:09<00:00, 193.36batch/s, loss_1=3.95e+3, loss_2=3.93e+3]
# Epoch 5/30: 100%|██████████| 1875/1875 [00:09<00:00, 191.72batch/s, loss_1=5.84e+3, loss_2=5.82e+3]
# Epoch 6/30: 100%|██████████| 1875/1875 [00:10<00:00, 186.48batch/s, loss_1=4.2e+3, loss_2=4.19e+3]
# Epoch 7/30: 100%|██████████| 1875/1875 [00:09<00:00, 197.76batch/s, loss_1=4.22e+3, loss_2=4.21e+3]
# Epoch 8/30: 100%|██████████| 1875/1875 [00:09<00:00, 197.56batch/s, loss_1=4.1e+3, loss_2=4.09e+3]
# Epoch 9/30: 100%|██████████| 1875/1875 [00:09<00:00, 197.42batch/s, loss_1=4.84e+3, loss_2=4.83e+3]
# Epoch 10/30: 100%|██████████| 1875/1875 [00:09<00:00, 194.99batch/s, loss_1=5.4e+3, loss_2=5.39e+3]
# Epoch 11/30: 100%|██████████| 1875/1875 [00:09<00:00, 197.48batch/s, loss_1=4.96e+3, loss_2=4.95e+3]
# Epoch 12/30: 100%|██████████| 1875/1875 [00:09<00:00, 196.88batch/s, loss_1=4.54e+3, loss_2=4.53e+3]
# Epoch 13/30: 100%|██████████| 1875/1875 [00:09<00:00, 197.06batch/s, loss_1=5.77e+3, loss_2=5.76e+3]
# Epoch 14/30: 100%|██████████| 1875/1875 [00:09<00:00, 195.51batch/s, loss_1=5.9e+3, loss_2=5.88e+3]
# Epoch 15/30: 100%|██████████| 1875/1875 [00:09<00:00, 194.07batch/s, loss_1=5.27e+3, loss_2=5.25e+3]
# Epoch 16/30: 100%|██████████| 1875/1875 [00:10<00:00, 186.00batch/s, loss_1=3.36e+3, loss_2=3.35e+3]
# Epoch 17/30: 100%|██████████| 1875/1875 [00:10<00:00, 185.97batch/s, loss_1=5.36e+3, loss_2=5.34e+3]
# Epoch 18/30: 100%|██████████| 1875/1875 [00:09<00:00, 192.40batch/s, loss_1=4.58e+3, loss_2=4.57e+3]
# Epoch 19/30: 100%|██████████| 1875/1875 [00:09<00:00, 194.70batch/s, loss_1=3.67e+3, loss_2=3.65e+3]
# Epoch 20/30: 100%|██████████| 1875/1875 [00:09<00:00, 194.84batch/s, loss_1=3.79e+3, loss_2=3.78e+3]
# Epoch 21/30: 100%|██████████| 1875/1875 [00:09<00:00, 192.78batch/s, loss_1=4.52e+3, loss_2=4.51e+3]
# Epoch 22/30: 100%|██████████| 1875/1875 [00:09<00:00, 193.52batch/s, loss_1=4.54e+3, loss_2=4.53e+3]
# Epoch 23/30: 100%|██████████| 1875/1875 [00:09<00:00, 192.24batch/s, loss_1=4.73e+3, loss_2=4.71e+3]
# Epoch 24/30: 100%|██████████| 1875/1875 [00:10<00:00, 181.20batch/s, loss_1=4.22e+3, loss_2=4.2e+3]
# Epoch 25/30: 100%|██████████| 1875/1875 [00:09<00:00, 188.39batch/s, loss_1=4.17e+3, loss_2=4.16e+3]
# Epoch 26/30: 100%|██████████| 1875/1875 [00:10<00:00, 186.71batch/s, loss_1=3.76e+3, loss_2=3.74e+3]
# Epoch 27/30: 100%|██████████| 1875/1875 [00:10<00:00, 187.19batch/s, loss_1=3.46e+3, loss_2=3.44e+3]
# Epoch 28/30: 100%|██████████| 1875/1875 [00:10<00:00, 187.33batch/s, loss_1=4.65e+3, loss_2=4.64e+3]
# Epoch 29/30: 100%|██████████| 1875/1875 [00:10<00:00, 185.78batch/s, loss_1=4.4e+3, loss_2=4.39e+3]
# Epoch 30/30: 100%|██████████| 1875/1875 [00:10<00:00, 185.43batch/s, loss_1=5.02e+3, loss_2=5e+3]
# ====================================Finish training====================================

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# Loss-Epoch Diagram

# %%
plt.rcParams["text.usetex"] = True
Loss_Epoch_Diagram = LOSS_EPOCH_DIAGRAM_TWO_LOSS(
    LOSS_HISTORY_TUPLE=(
        Loss_1_Training_History,
        Loss_1_Validation_History,
        Loss_2_Training_History,
        Loss_2_Validation_History,
    ),
    CONFIG=config
)

# %% [markdown]
# Final loss.

# %%
Loss_2_Validation_History[-1]
# Out:
# 4662.420055138001

# %% [markdown]
# Linear Mapping Matrix Visualization.

# %%
data_temp = Net.LinearMapping.weight.detach().to("cpu").numpy()
Linear_Mapping_Weight = VISUALIZE_MATRIX(
    data_temp, config["VISUALIZATION"]["LINEAR_MAPPING_WEIGHT"], "Linear Mapping Weight"
)

# %% [markdown]
# Linear Layer Weight Visualization.

# %%
NN_Weight = VISUALIZE_NN(Net.NN, config["VISUALIZATION"]["NN_WEIGHT"])

# %% [markdown]
# ## 4. Error on Test Data

# %% [markdown]
# Test Data

# %%
test_input_data = []
test_output_data = []
for data in TestLoader:
    test_input_data += data[0].detach().to(GET_DEVICE(config["TRAIN"]["DEVICE"]))
    test_output_data += data[1].detach().to("cpu")

test_output_fromData = torch.stack(test_output_data).numpy()

# %% [markdown]
# Obtain output computed from model.

# %%
Net.eval()
test_ouput_fromModel = torch.stack(
    [Net(test_input).detach().to("cpu") for test_input in test_input_data]
).numpy()

# %% [markdown]
# Compute standard deviation and extreme error of each element.

# %%
import itertools

StandardDeviation = np.zeros((1, test_ouput_fromModel.shape[1]))
ExtremeError = test_ouput_fromModel[:2, :] - test_output_fromData[:2, :]
for i, j in itertools.product(
    range(test_ouput_fromModel.shape[0]), range(test_ouput_fromModel.shape[1])
):
    StandardDeviation[:, j] += np.power(
        test_ouput_fromModel[i, j] - test_output_fromData[i, j], 2
    )
    ExtremeError[0, j] = max(
        ExtremeError[0, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
    ExtremeError[1, j] = min(
        ExtremeError[1, j], (test_ouput_fromModel[i, j] - test_output_fromData[i, j])
    )
StandardDeviation = np.sqrt(StandardDeviation) / test_ouput_fromModel.shape[0]
StandardDeviation = StandardDeviation.reshape(
    -1,
).tolist()
UpperError = ExtremeError[0, :].tolist()
LowerError = ExtremeError[1, :].tolist()

# %% [markdown]
# Visualization.

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Standard Deviation
axs[0].bar(np.arange(len(StandardDeviation)) + 1, StandardDeviation, zorder=5)
axs[0].set_xticks(np.linspace(1, len(StandardDeviation) + 1, 20, dtype=int))
axs[0].set_xlim([1 - 0.8, len(StandardDeviation) + 0.8])
axs[0].set_title("Standard Deviation of MLP", fontsize=20)
axs[0].set_xlabel("Term", fontsize=15)
axs[0].set_ylabel("Standard Deviation", fontsize=15)
axs[0].grid(axis="y", linestyle="--", zorder=-1)


# Upper Error
axs[1].bar(np.arange(len(UpperError)) + 1, UpperError, zorder=5)
# Lower Error
axs[1].bar(np.arange(len(LowerError)) + 1, LowerError, zorder=5)
axs[1].set_xticks(np.linspace(1, len(StandardDeviation) + 1, 20, dtype=int))
axs[1].set_xlim([1 - 0.8, len(UpperError) + 0.8])
axs[1].set_title("Extreme Error of MLP", fontsize=20)
axs[1].set_xlabel("Term", fontsize=15)
axs[1].set_ylabel("Min/Max Error", fontsize=15)
axs[1].grid(axis="y", linestyle="--", zorder=0)

plt.tight_layout()
plt.show()
